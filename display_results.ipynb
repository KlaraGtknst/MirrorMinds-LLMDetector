# %% [markdown]
# # Display results

# %%
import pandas as pd

# %%
loaded_samples_essays = pd.read_pickle("Datasets/sample_essays.pkl")
print("Loaded DataFrame:")
display(loaded_samples_essays)
# Out:
# Loaded DataFrame:
#                                                Essay
# 0  Technology has drastically changed the way we ...
# 1  Climate change poses a serious threat to the e...
# 2  Education plays a vital role in shaping the fu...
# 3  The rise of social media has influenced politi...
# 4  Healthcare systems need to be more accessible ...

# %%
loaded_gen_questions = pd.read_pickle("Datasets/generated_questions.pkl")
print("Loaded DataFrame:")
display(loaded_gen_questions)
# Out:
# Loaded DataFrame:
#                                                Essay prompt_generation_time  \
# 0  Technology has drastically changed the way we ...               1.793715
# 1  Climate change poses a serious threat to the e...               0.706179
# 2  Education plays a vital role in shaping the fu...               0.492621
# 3  The rise of social media has influenced politi...                 0.4808
# 4  Healthcare systems need to be more accessible ...               0.473739
#
#                                               prompt
# 0  What technology has drastically changed the wa...
# 1  What does climate change pose a serious threat...
# 2  What role does education play in shaping the f...
# 3  What type of media has influenced political di...
# 4  What needs to be more accessible and equitable...

# %%
loaded_gen_responses = pd.read_pickle("Datasets/generated_responses.pkl")
print("Loaded DataFrame:")
display(loaded_gen_responses)
# Out:
# Loaded DataFrame:
#                                                Essay prompt_generation_time  \
# 0  Technology has drastically changed the way we ...               1.793715
# 1  Climate change poses a serious threat to the e...               0.706179
# 2  Education plays a vital role in shaping the fu...               0.492621
# 3  The rise of social media has influenced politi...                 0.4808
# 4  Healthcare systems need to be more accessible ...               0.473739
#
#                                               prompt  \
# 0  What technology has drastically changed the wa...
# 1  What does climate change pose a serious threat...
# 2  What role does education play in shaping the f...
# 3  What type of media has influenced political di...
# 4  What needs to be more accessible and equitable...
#
#                                       generated_text generation_time
# 0                                         a computer       10.548684
# ...
